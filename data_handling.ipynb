# %% [markdown]
# ## A region based sales data

# %%
# Imports
import pandas as pd

# %%
sales_data = pd.DataFrame({
    "region": ["Greater Accra", "Ashanti", "Western", "Eastern", "Volta", "Bono"],
    "product": ["Tilapia", "Cassava", "Maize", "Potatoes", "Rice", "Yam"],
    "sales": [216, 82, 110, 108, 154, 115]
})

# %%
sales_data.head()
# Out:
#           region   product  sales
# 0  Greater Accra   Tilapia    216
# 1        Ashanti   Cassava     82
# 2        Western     Maize    110
# 3        Eastern  Potatoes    108
# 4          Volta      Rice    154

# %%
sales_data.shape
# Out:
# (6, 3)

# %%
sales_data.dtypes
# Out:
# region       str
# product      str
# sales      int64
# dtype: object

# %%
sales_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   region   6 non-null      str
#  1   product  6 non-null      str
#  2   sales    6 non-null      int64
# dtypes: int64(1), str(2)
# memory usage: 276.0 bytes

# %%
sales_data.describe()
# Out:
#             sales
# count    6.000000
# mean   130.833333
# std     47.709188
# min     82.000000
# 25%    108.500000
# 50%    112.500000
# 75%    144.250000
# max    216.000000

# %%
sales_data.loc[:, "sales"]
# Out:
# 0    216
# 1     82
# 2    110
# 3    108
# 4    154
# 5    115
# Name: sales, dtype: int64

# %%
sales_data.iloc[0,1]
# Out:
# 'Tilapia'

# %%
#Add a new row to the dataframe
sales_data.loc[len(sales_data)] = ["Northern", "Millet", None]

# %%
sales_data
# Out:
#           region   product sales
# 0  Greater Accra   Tilapia   216
# 1        Ashanti   Cassava    82
# 2        Western     Maize   110
# 3        Eastern  Potatoes   108
# 4          Volta      Rice   154
# 5           Bono       Yam   115
# 6       Northern    Millet   NaN

# %%
# Remove row with missing value
sales_data.dropna(inplace=True)

# %%
sales_data
# Out:
#           region   product sales
# 0  Greater Accra   Tilapia   216
# 1        Ashanti   Cassava    82
# 2        Western     Maize   110
# 3        Eastern  Potatoes   108
# 4          Volta      Rice   154
# 5           Bono       Yam   115

# %%
#Add the row with missing column again
sales_data.loc[len(sales_data)] = ["Northern", "Millet", None]

# %%
sales_data
# Out:
#           region   product sales
# 0  Greater Accra   Tilapia   216
# 1        Ashanti   Cassava    82
# 2        Western     Maize   110
# 3        Eastern  Potatoes   108
# 4          Volta      Rice   154
# 5           Bono       Yam   115
# 6       Northern    Millet   NaN

# %%
#Fill missing 
sales_data.fillna(0)
# Out:
#           region   product sales
# 0  Greater Accra   Tilapia   216
# 1        Ashanti   Cassava    82
# 2        Western     Maize   110
# 3        Eastern  Potatoes   108
# 4          Volta      Rice   154
# 5           Bono       Yam   115
# 6       Northern    Millet     0

# %%
sales_data.fillna(0)
# Out:
#           region   product sales
# 0  Greater Accra   Tilapia   216
# 1        Ashanti   Cassava    82
# 2        Western     Maize   110
# 3        Eastern  Potatoes   108
# 4          Volta      Rice   154
# 5           Bono       Yam   115
# 6       Northern    Millet     0

# %%
sales_data.groupby("region")["sales"].mean()
# Out:
# region
# Ashanti           82.0
# Bono             115.0
# Eastern          108.0
# Greater Accra    216.0
# Northern           NaN
# Volta            154.0
# Western          110.0
# Name: sales, dtype: object
